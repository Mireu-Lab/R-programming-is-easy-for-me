# %% [markdown]
# <a href="https://colab.research.google.com/github/Mireu-Lab/R-programming-is-easy-for-me/blob/main/page336_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages('DAAG')
install.packages('plotrix')
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(DAAG)

ds = table(science$like)
pie(ds, main = '선호 점수별 비율',
    col=rainbow(length(ds)),
    radius = 1)
# Out:
# Plot with title “선호 점수별 비율”

# %%
library(plotrix)

ds = table(science$State)
pie3D(ds, main = '주별 학생 비율',
    labels=names(ds),
    labelscex=1.0,
    explode=0.1,
    radius = 1.5,
    col=c('brown', 'green'))
# Out:
# Warning message in plot.window(...):
# “"labelscex" is not a graphical parameter”
# Warning message in plot.xy(xy, type, ...):
# “"labelscex" is not a graphical parameter”
# Warning message in title(...):
# “"labelscex" is not a graphical parameter”
# Plot with title “주별 학생 비율”

# %%
year = 1875:1972
ds = data.frame(year, LakeHuron)

plot(ds$year, ds$LakeHuron,
     main = '수위 변화',
     xlab = '연도', ylab = '수위',
     type='b', lty = 1,
     col = 'blue')
# Out:
# Plot with title “수위 변화”
